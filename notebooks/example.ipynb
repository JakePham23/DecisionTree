# %% [markdown]
# # Phân tích bộ dữ liệu `Example`

# %% [markdown]
# ## 1. Preparing datasets

# %%
# %pip install numpy matplotlib seaborn graphviz

# --- Thư viện cơ bản ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import graphviz
import os

# --- Thư viện cho Machine Learning ---
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# --- Định nghĩa các đường dẫn ---
# Đi từ `notebooks` ra ngoài một cấp để thấy các thư mục khác
DATA_PATH = '../data/example.csv'
OUTPUT_DIR = '../outputs/example/'
# Tạo thư mục output nếu nó chưa tồn tại
os.makedirs(OUTPUT_DIR, exist_ok=True)


# thêm các thay đổi cần thiết
# ví dụ 
# Load data
df = pd.read_csv(DATA_PATH)

# Tách Feature và Label (Ví dụ cho Diabetes: cột cuối là label 'class')
# Lưu ý: Sửa 'class' thành tên cột label thực tế của từng dataset
X = df.iloc[:, :-1] 
y = df.iloc[:, -1]  

# Xử lý One-Hot Encoding nếu cần
X = pd.get_dummies(X, drop_first=True)

# Define các tỉ lệ train/test theo đề bài
ratios = [0.4, 0.6, 0.8, 0.9] # Tương ứng test_size = 0.6, 0.4, 0.2, 0.1
subsets = {}

for r in ratios:
    test_size = 1 - r
    # Quan trọng: stratify=y để đảm bảo tỉ lệ class cân bằng
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, stratify=y, random_state=42
    )
    subsets[f"{int(r*100)}_{int(test_size*100)}"] = (X_train, X_test, y_train, y_test)
    
    print(f"Split {int(r*100)}/{int(test_size*100)} - Train shape: {X_train.shape}, Test shape: {X_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 27
#      21 os.makedirs(OUTPUT_DIR, exist_ok=True)
#      24 # thêm các thay đổi cần thiết
#      25 # ví dụ
#      26 # Load data
# ---> 27 df = pd.read_csv(DATA_PATH)
#      29 # Tách Feature và Label (Ví dụ cho Diabetes: cột cuối là label 'class')
#      30 # Lưu ý: Sửa 'class' thành tên cột label thực tế của từng dataset
#      31 X = df.iloc[:, :-1]
#
# ...

# %% [markdown]
# ## 2. Building and Evaluating the decision tree classifiers

# %% [markdown]
#  **Có cần nếu có để biết print cho hiểu**

# %% [markdown]
# ## 3. The depth and accuracy of a decision tree
